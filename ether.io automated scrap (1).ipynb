# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import math

# %%
HEADERS = {'User-Agent': 'Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148'}

# %%
k=1
id=[]
b=[]
t=[]
v=[]
m=[]
txn=[]
from1=[]
while(k<=6):
    url1=f'https://etherscan.io/txs?a=0x1f9090aae28b8a3dceadf281b0f12828e676c326&ps=100&p={k}'
    page=requests.get(url1, headers=HEADERS)
    soup = BeautifulSoup(page.content, "html.parser")
    
    for row in soup.select('table.table-hover tbody tr'):
        cells = row.findAll('td')
        for i in cells[1]:
            id.append(i.text)
        for i in cells[4]:
            m.append(i.text)
        for i in cells[3]:
            b.append(i.text)
        for i in cells[7]:
            from1.append(i.text)
        for i in cells[9]:
            t.append(i.text) 
        for i in cells[10]:
            v.append(i.text) 
        for i in cells[11]:
            txn.append(i.text)
    k=k+1

# %%
for j in range(len(id)):
    id[j]=id[j].replace('\n','')
    from1[j]=from1[j].replace('\n','')
    t[j]=t[j].replace('\n','')

# %%
original_list = txn
tax = [''.join(original_list[i:i+3]) for i in range(0, len(original_list), 3)]

# %%
import pandas as pd 
  
# initialize data of lists. 
data = {'Txn Hash': id, 
        'Block': b,'Time': m,'From': from1,'Value': v,'Txn Fee':tax} 
  
# Create DataFrame 
df = pd.DataFrame(data)

# %%
df
# Out:
#                                               Txn Hash     Block  \
# 0    0x00454211e9a70cacf0fa0d29f60479d26ac6f4eddb23...  18584479
# 1    0x328760acee3868c19b15ce1423071027dc4fcb8ee9b2...  18584477
# 2    0xe6ecf2ed110c45a44074e012387564b8aa26343fe944...  18584476
# 3    0xf4976bb711c4982091174ff341387f3410972eea9fbb...  18584469
# 4    0xccc4ac2d4c5d7886642597653769d2ac316424c04930...  18584469
# ..                                                 ...       ...
# 595  0x9cedc4b6956a4237e220124e38f2dc4ecddac425967f...  18582854
# 596  0xb459cd43ef4c8c9cb9c7b5574d98540327c45149404d...  18582853
# 597  0x3de66107915352bd96434d32ea0cb48e9e44c215546f...  18582849
# 598  0x74f564664693b73d877bf6716b85fd7bafa2c0542576...  18582846
# 599  0x856807e29ef612975a8a07c3205e5c054095067bfad6...  18582845
#
#                     Time                From            Value     Txn Fee
# 0    2023-11-16 12:34:47  rsync-builder.eth   0.022121555 ETH  0.00076003
# ...
